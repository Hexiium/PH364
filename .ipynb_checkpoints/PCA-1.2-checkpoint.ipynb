# %% [markdown]
# # Pre-class Assignment 1.2
#
# **Due Tuesday night of Week 1**

# %% [markdown]
# If you try to edit and save this file, and it simply isn't working, that's because it's not supposed to (yet).
#
# The whole class has access to this file, and you need to make your own in order to save your progress. To create your own version, look at the file browser on the left sidebar, right-click on this file, then click "Copy". You should have your own directory titled `📁/username/`. Navigate to your directory and "Paste" the file there by right-clicking in the whitespace. Then you can open it, make edits, and save them.

# %% [markdown]
# *Edit this cell, and then save your work!*
#
# #### &#x2705; Owen Sliger

# %% [markdown]
# Pre-class assignments will be composed of a combination of videos, text to read, and small assignments. The goal of these assignments is to prepare you for class the following day. You should watch the videos and read the text, and then do the assigned work. You will be graded on making a good-faith effort, not on absolute correctness!
#
# This assignment is due by **11:59pm** the day before class, and should be uploaded into the assignment submission on Canvas.

# %% [markdown]
# ---
#
# ## Navigating directories using the terminal

# %% [markdown]
# First off, in order to work through this assignment, you will need to use the JupyterHub interface. If you're already running this notebook there – you're all set! If you have been working on this notebook on your local Python installation up to this point, you should save it, and then upload it to the JupyterHub and continue working on it there.
#
# The following video will introduce you to the Jupyterhub Terminal program which is a Command-Line Interface (CLI) that can be used for work done in this class. I highly recommend that you follow along and practice executing the same commands as the video.

# %%
# the commands below this comment imports the YouTube Video module and then displays
# a specific YouTube video, with a given width and height.  You can watch the video
# in full-screen mode, which can be easier to see, by clicking the little box in the
# bottom-right corner of the video.

from IPython.display import YouTubeVideo
YouTubeVideo('1lN06HH5ttU', width=800, height=450)

# %% [markdown]
# If the YouTube video didn't load, you can access a MediaSpace version here:
# https://media.oregonstate.edu/media/t/1_bp3ubnn0

# %% [markdown]
# Now that you've had a chance to learn a bit about using the command-line interface in the terminal, review the commands below and add a short description for each of them.
#
# **&#x2705; Do this:** Modify the following list to include short (just a few words) descriptions for each command as it was presented in the video. A couple descriptions are provided for you as examples.

# %% [markdown]
# `clear`: Clears all previous commands
#
# `pwd`: Prints the current working directory, telling you what file directory you are currently using the terminal in
#
# `ls`: Lists all files in the directory that are accessible
#
# `cd junk`: Changes to the directory named junk
#
# `cd ..`: Changes the directory that the terminal is operating in to the parent file, going up in the directory (inter file -> outer file)
#
# `cd ~`: Returns the terminal to the user directory
#
# `touch foo.py`: Creates a python plain text file named foo
#
# `rm trash`: Removes a file named trash
#
# `rm -r junk`: Removes a directory named junk (-r is a flag that acts recursively)
#
# `cat trash`: Displays the contents of a file named trash (concatenate)

# %% [markdown]
# **&#x2705; Do this:** What is the name of the command for creating a new directory in the terminal program?
#
# `mkdir` : Make directory

# %% [markdown]
# ---
#
# ## Linking a local and a remote repository

# %% [markdown]
# Now that we can make directories and files, we have enough to start making a local git repository! This next video will walk through the process of creating a local repository for the first time on JupyterHub, and linking it to a remote GitHib repo.
#
# Once again, try to follow along and practice executing the same commands as the video. To fully execute all the commands shown, you'll first need a GitHub repository to connect to. You create one of your own, or you can browse and choose from one of the many thousands of publicly available repositories on GitHub: https://github.com/search?q=physics&type=repositories

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('WHhSx5H822s', width=800, height=450)

# %% [markdown]
# If the YouTube video didn't load, you can access a MediaSpace version here: https://media.oregonstate.edu/media/t/1_3nbh3tma

# %% [markdown]
# To learn more about the history of renaming `master` to `main`, you can read about it here: https://web.archive.org/web/20210610043151/https://www.wired.com/story/tech-confronts-use-labels-master-slave/

# %% [markdown]
# **&#x2705; Do this:** What is the difference between `ls` and `ls -a`?
#
# `ls` lists all the visible files and folders in a directory, while `ls -a` shows all files and folders, including hidden ones such as .gitconfig

# %% [markdown]
# **&#x2705; Do this:** Follow along the steps in the video again, this time creating a local repo for your version of the PH 364 Course Wiki, and linking it to the course wiki GitHub repository: https://github.com/hamerski/PH-364-S26-wiki

# %% [markdown]
# ---
#
# ## Pushing changes from local to remote

# %% [markdown]
# The last part of this pre-class assignment covers making changes and pushing them to the remote repository that your local JupyterHub repo is linked to. In following along to this video, you'll need to be an **owner** or **collaborator** of the remote GitHub repository that you are linked to. In the previous part, if you only linked to the course wiki or to a public repo that you found while browsing, you'll first need to make a GitHub repo of your own.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('26InnsFDFpM', width=800, height=450)

# %% [markdown]
# If the YouTube video didn't load, you can access a MediaSpace version here: https://media.oregonstate.edu/media/t/1_p1qjjhv3

# %% [markdown]
# **&#x2705; Do this:** What are the all the ways you can think to display the contents of a file in the terminal? List them below
#
# `cat` directly displays the contents of a file in the terminal
#
# `vi` displays the text contents of a file and allows it to be edited

# %% [markdown]
# After following along the video, you should have modified your `.gitconfig` file a couple different times.
#
# **&#x2705; Do this:** Display the contents of your `.gitconfig` file in your terminal, and then copy and paste them below:
#
# ```
# [credential]
#         helper = cache
# [init]
#         defaultBranch = main
# [user]
#         email = sligero@oregonstate.edu
#         name = Owen JupyterHub
# ```

# %% [markdown]
# Before there was Google Docs or even Microsoft Word, programmers needed a simple way to write a text file. Previously, all code was written on physical punch cards. Even before the punch cards, the first electronic computer programmers worked with a series of cables in a huge room where the ENIAC computer lived: https://www.aps.org/apsnews/2022/11/eniac-first-top-secret-program
#
# Being able to go from punch cards, to dynamically editing code/text stored in the computer using the computer itself, would be a giant leap forward in terms of human-computer interaction! This is the world in which `vi` was born.
#
# <div class="alert alert-block alert-info">
# <b>Note:</b> Make sure to read the following content. The commands take a little getting used to, but it is an incredibly useful tool.</div>
#
# - To open a file in `vi` on the command line, you need to type `vi filename` into the CLI (replace `filename` with your file). This will open the file and dump you into the vim text editor
# - When you first open `vi`, you will not be able to immediately type things to make modifications like you might be used to. Instead, you will start out in the `vi` "command mode," which allows you to manipulate the file using specific letter-based commands.
# - To enter the text-editing mode you're familiar with, you need to press `i` which puts you in "insert mode." From here, you can type normally.
# - When you are done typing in insert mode, you need to press `ESC`, which takes you back to command mode.
# - If you're happy with everything you've done, you can type `:wq`, which will "write" (`w`) and then "quit" (`q`). If you ever want to quit without saving your changes, you can use `:q!`.
# - For more vi commands, check out this [cheat sheet](https://ryanstutorials.net/linuxtutorial/cheatsheetvi.php).

# %% [markdown]
# **&#x2705; Do this:** Use the directions above to make a new file in your JupyterHub, put some text in it, and save it. Specifically, do the following:
#
# - Open a new file called `new_file.txt` using `vi`.
# - Enter Insert mode.
# - Type some text into the file.
# - Write the contents of your new file and quit `vi`.

# %% [markdown]
# ### That's all! You've reached the end of the pre-class assignment.
#
# Scroll through to make sure you didn't miss any tasks (marked with &#x2705;). Download your work as an HTML file, by selecting: `File` --> `Save and Export Notebook As...` --> `HTML` inside the JupyterHub interface (don't select your browser's File menu).
#
# Open your downloaded file to ensure the contents look okay, then submit it on Canvas.
