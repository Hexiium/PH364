# %% [markdown]
# # In-class Assignment 2.1
#
# **Week 2 Monday**

# %% [markdown]
# #### &#x2705; Owen Sliger, Ethan Hogan, Keller Mcgough, Dengqian Ken Zhang

# %% [markdown]
# In PCA 2.1, you spent some time considering the assumptions that go into choosing a model. Those assumptions can depend on the question you are asking, and they can also depend on the resources you have for building an actual model.
#
# You also spent some time using 2D NumPy arrays, which are an example of a resource that could be relevant for building a model of a magnet based on a 2D lattice of spins.
#
# In today's ICA, you will learn about several resources we have for modeling a magnetic material in this way, and you will plan out how you and group could create such a model.

# %% [markdown]
# ---
#
# ## Part 1: Breaking a question up
#
# One process we will practice doing is **going from question to assumptions**. In this process, a big, lofty question can be chunked into more simplified pieces.
#
# Consider the clarification we made in PCA 2.1.
#
# We started with: **"How hot can a magnet get until it's not a magnet anymore?"**
#
# We refined that question to: **"How do atoms in a magnetic material behave at different temperatures?"**
#
# This takes a question about the whole magnet, and makes it about individual atoms in the magnet. We also made an assumption that these atoms could be modeled using a 2D lattice of the up and down spin orientations of their electrons.

# %% [markdown]
# &#x2705; As a group, consider the 2D spins-lattice model. What parts of the refined question does this model help address? What parts are still missing or unknown?
#
# The lattice model addresses the individual properties of the atoms in the magnet instead of some arbitrary magnet object as a whole. Using the spin properties of each particle in the lattice, we can see the overall magenetic properties of the lattice, allowing us to adress how the spin pattern changes the magnetic properties of the material. However, since we only know the geometric structure of the lattice and their assigned spins we cannot address any of the changing elements, such as the spin of the atoms as the temperature changes.

# %% [markdown]
# ---
#
# ## Part 2: Analyzing a 2D lattice model
#
# The 2D lattice can be a nice visual simplication, but how can we apply it in a way that enables us to learn about physics? As with many physics phenomena, we can begin with energy.

# %% [markdown]
# The energy (also called Hamiltonian) of the entire lattice is
#
# $$E_{\text{total}} = - \sum_{\langle a,b \rangle}  s_a s_b \text{,}$$
#
# where $\langle a,b \rangle$ indicates all pairs of immediately adjacent spins $a$ and $b$.
#
# Most spins in the system will have **four adjacent neighbors**, except the spins on the outer edge of the lattice.
#
# <img src="https://raw.githubusercontent.com/pattihamerski/PH-36X-Public/refs/heads/main/367/images/four-neighbors.png"
#      alt="Energy is calculated by comparing a spin with its four neighbors"
#      width="400"
# />

# %% [markdown]
# &#x2705; It important to get a feeling for new physics concepts and formulas before writing code. Use this definition for the energy to calculate energies of baby lattices (2x2 or 3x3) on a whiteboard.
#
# Jake observed

# %% [markdown]
# &#x2705; What is an assumption that is baked into this formula for energy?
#
# This equation assumes that the only energy in the system in the magnetic potential, i.e. there is no kenetic energy.

# %% [markdown]
# ---
#
# ## Part 3: Monte Carlo modeling
#
# We use computing to create models, in part because it provide capabilities like animation and randomization, which can't be achieved using pen and paper alone. One such model, that can only be created computationally (except for very simple examples), is a Monte Carlo simulation. Monte Carlo is a set of simulation algorithms that use probability distributions to model the evolution of a system.
#
# We can use the [**Metropolis algorithm**](https://en.wikipedia.org/wiki/Metropolis%E2%80%93Hastings_algorithm) (a specific type of Monte Carlo method) to model a 2D lattice of spins.

# %% [markdown]
# The algorithm can be broken into these steps:
#
# 1. Establish an initial configuration of a system
# 2. Randomly generate a possible change to the system
# 3. Calculate the probability of accepting that change
# 4. Accept or reject the change based on that probability
# 5. Go back to Step 2 and repeat the algorithm

# %% [markdown]
# If the system being modeled is the 2D lattice of spins, we can model the probability like this:
#
# $$\mathcal{P}(\text{accept}) = \begin{cases}
# 1 & \text{ if d}E \le 0 \\
# e^{-\text{d}E/T} & \text{ if d}E > 0
# \end{cases}$$
#
# This comes from the Boltzmann distribution.

# %% [markdown]
# &#x2705; Rewrite the five steps of the Metropolis algorithm for the 2D lattice model.
#
# 1. Generate a lattice with random spin 1/2 particles.
# 2. Flip the sign of a random particle.
# 3. Calculate if the change should be accepted according to P(accept) depending on if the system gains or loses energy and its probability with temperature.
# 4. If P(accept) determines that the change is accepted, submit the change.
# 5. Go back to step 2 and repeat the algorithm.

# %% [markdown]
# ---
#
# ## Part 4: Implementing an algorithm
#
# How could we implement this algorithm computationally?
#
# You might be tempted to start coding, but first, you'll need to plan out your approach. If you start to code before knowing your end-goal and planning out the steps along the way, it will take you at least twice as long.

# %% [markdown]
# &#x2705; The first step to planning is setting a goal. What do you want to achieve through implementing the Metropolis algorithm for a 2D lattice of spins?
#
# We would like to acheive a program that shows how the lattice evolves at different temperatures and comparing the different spin patterns to show the relationship between temperature and magnetic properties. Changing the temperature will change the probability that certain changes will be expected. So, as we change temperature, and run the algorithm for a certain number of steps, we can see spin patterns evolve in different lattices, reflecting how magnetic the material is.

# %% [markdown]
# &#x2705; Next, consider how you will get to your goal. Luckily, the algorithm is already split into steps. Do you need to alter them in any way to ensure you can meet your goal?
#
# It would be in our interest to create a predetermined spin structure for the lattice to make it magnetic at the start instead of a random assortment of spins. We would need to add some way to save a lattice and/or its magnetic,spin, or energy to compare how the temperature changes the outcome. To do this we will sum all of the spin particle values and taking the absolute value to see how magnetized the lattice is. This would allow us to make a graph of magnetism and temperature.

# %% [markdown]
# Lastly, you can map out the steps of your algorithm based on the computing tools you'll need to implement each step. At this stage, it can be helpful to split bigger steps into multiple, smaller steps. You can also use this process to flag places where there are missing or unknown pieces -- this is when you don't necessarily know the computing tools you might need, but you can describe the process in words.
#
# &#x2705; How can you break up the steps of your algorithm into more doable chunks in terms of the coding? What steps seem to have missing or unknown components that you're not sure how to code?

# %% [markdown]
# - Create lattice with determined spin structure
